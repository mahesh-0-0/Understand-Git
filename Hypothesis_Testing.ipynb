# %% [markdown]
# # 🎯 Hypothesis Testing
# ### 1) Assumption : Something which we assume to be
#
# ### 2) Data : Data is that to tell assumption is correct or not (Evidance) / To support or negate the assumption

# %% [markdown]
# #### Hypothesis testing is a statistical method that is used to make a statistical decision using experimental data. Hypothesis testing is basically an assumption that we make about a population parameter. It evaluates two mutually exclusive statements about a population to determine which statement is best supported by the sample data.
#
# ####  Hypothesis testing is a procedure, based on sample evidence and probability, used to test claims regarding a characteristic of a population.
#
#  - #### **Defining Hypotheses**
#   1) Null Hypothesis (H0) : Default assumption or a basic assumption
#  made based on the problem knowledge
#
#   2) Alternative Hypothesis (Ha) : It is opposite of Null Hypothesis, i.e. Having evidance data to conclude that default assumption is false

# %% [markdown]
# #### P-value : P-value is defined as the Probability of obtaining results at least as extreme as the observed results, under the assumption that the Null Hypothesis (Innocence) is true. Therefore, if p-value is low -> Reject  H0
#
# When using in applications, we compare the p-value with a **threshold value (α)**, and if it is less than that, then we reject the $H_0$.
#
# This threshold is known as **significance level**.

# %% [markdown]
# #### **Judge Example**
#
# - A person comes into court charged with a crime. A judge must decide whether the person is innocent (null hypothesis) or guilty (alternative hypothesis). Even though the person is charged with the crime, at the beginning of the trial (and until the judge declares otherwise) the accused is assumed to be innocent. Only if overwhelming evidence of the person's guilt can be shown is the judge expected to declare the person guilty--otherwise the person is considered innocent.
#
#   - #### **Errors**
#   Two types of Errors
#
#     1) the person is innocent but the judge finds the person guilty (Type I Error) : the null hypothesis is true but the decision based on the testing process is that the null hypothesis should be rejected (False Positive). We call the probability of making a Type-I Error as **alpha (*α*)**
#
#     2) the person is guilty but the judge declares the person to be innocent (Type II Error) : the null hypothesis is false but the testing process concludes that it should be accepted (False Negative). We call the probability of making a Type-II Error as **beta (*β*)**
#
#     Type I error is usually considered more serious than a Type II error
#
#     ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
((1.28)*((0.7)/np.sqrt(45))) + 3.5
# Out:
# 3.6335677938559874

# %%
p_value
# Out:
# 0.3201414388838406

# %%
import numpy as np
from scipy import stats


# Null hypothesis: The population means of fuel efficiency for Engine X and Engine Y are the same.
# Alternative hypothesis: One engine type is more fuel-efficient than the other.

# Define the function to calculate the test statistic and corresponding p-value
def TwoSampZTest(samp_mean_1, samp_mean_2, samp_std_1, samp_std_2, n1, n2):
  # Calculate the test statistic
  denominator = np.sqrt((samp_std_1**2 / n1) + (samp_std_2**2 / n2))
  z_score = (samp_mean_1 - samp_mean_2) / denominator
  return z_score


# Given data
sample_mean_X = 120 # Average fuel efficiency for Group X (Engine X)
sample_mean_Y = 110 # Average fuel efficiency for Group Y (Engine Y)
sample_std_X = 15 # Standard deviation for Group X
sample_std_Y = 12 # Standard deviation for Group Y
significance_level = 0.05
sample_size_X = 30 # Sample size for Group X
sample_size_Y = 35 # Sample size for Group Y


# Calculate the z-score using the function
z_score = TwoSampZTest(sample_mean_X, sample_mean_Y, sample_std_X, sample_std_Y, sample_size_X, sample_size_Y)

# Calculate the two-tailed p-value
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# A two-tailed z-test considers deviations from the null hypothesis in both positive and negative directions.
# Using abs(z_score) ignores the sign of the deviation, focusing solely on its magnitude, ensuring we consider both directions and calculate the accurate two-tailed p-value.

# Compare the p-value to the significance level
if p_value < significance_level:
  conclusion = "Reject the null hypothesis. Engine Y is more fuel-efficient."
else:
  conclusion = "Fail to reject the null hypothesis. No significant difference in fuel efficiency."

print(f'z-score: {z_score:.4f}')
print(f'p-value: {p_value:.4f}')
print('Conclusion:', conclusion)
# Out:
# z-score: 2.9343
# p-value: 0.0033
# Conclusion: Reject the null hypothesis. Engine Y is more fuel-efficient.

# %%
import numpy as np
import scipy.stats as stats

# Define the data
# Number of satisfied customers
satisfied_customers = 65
# Total number of customers in the sample
total_customers = 100

# Specify the target satisfaction level (null hypothesis)
target_satisfaction = 0.70  # 70%

# Define the hypotheses
# Null Hypothesis (H0): The proportion of satisfied customers is equal to the target satisfaction level.
# Alternative Hypothesis (Ha): The proportion of satisfied customers is not equal to the target satisfaction level.
p = target_satisfaction

# Calculate the test statistic (Z)
# p_hat = sample proportion
p_hat = satisfied_customers / total_customers
n = total_customers
Z = (p_hat - p) / np.sqrt((p * (1 - p)) / n)

# Interpret the test statistic
# Z follows a standard normal distribution. We will calculate the two-tailed p-value next.

#Calculate the p-value
p_value = stats.norm.cdf(np.abs(Z))

# Print the results
print(f"Z-statistic = {Z}")
print(f"P-value = {p_value}")


alpha = 0.05  # Significance level
if p_value < alpha:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

if decision == "Reject the null hypothesis":
    conclusion = "There is significant evidence to suggest that the archers' actual success rate is greater than 70%."
else:
    conclusion = "There is no significant evidence to suggest that the archers' actual success rate is greater than 70%."

# Print the results
print(f"Decision: {decision}")
print(f"Conclusion: {conclusion}")
# Out:
# Z-statistic = -1.0910894511799603
# P-value = 0.8623832379625824
# Decision: Fail to reject the null hypothesis
# Conclusion: There is no significant evidence to suggest that the archers' actual success rate is greater than 70%.

# %%
import statsmodels.api as sm
import numpy as np

# Define the data
conversions = np.array([41, 351])  # Number of conversions for Web Page A and Web Page B
visits = np.array([195, 605])  # Number of visits for Web Page A and Web Page B

# Perform the Z-proportions test
z_stat, p_value = sm.stats.proportions_ztest(conversions, visits, alternative='two-sided')

# Print the results
print(f"Z-statistic = {z_stat}")
print(f"P-value = {p_value}")

# Make a decision and conclusion
if p_value < alpha:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

if decision == "Reject the null hypothesis":
    conclusion = "the proportions of Drug A and Drug B are significantly different."
else:
    conclusion = "no significant difference in the proportions of Drug A and Drug B"

# Print the results
print(f"Decision: {decision}")
print(f"Conclusion: {conclusion}")
# Out:
# Z-statistic = -8.985900954503084
# P-value = 2.566230446480293e-19
# Decision: Reject the null hypothesis
# Conclusion: the proportions of Drug A and Drug B are significantly different.

# %%
import statsmodels.api as sm
import numpy as np

# Define the data
conversions = np.array([40, 60])  # Number of conversions for Web Page A and Web Page B
visits = np.array([180, 200])  # Number of visits for Web Page A and Web Page B

# Perform the Z-proportions test
z_stat, p_value = sm.stats.proportions_ztest(conversions, visits, alternative='two-sided')

# Print the results
print(f"Z-statistic = {z_stat}")
print(f"P-value = {p_value}")

# Make a decision and conclusion
if p_value < alpha:
    decision = "Reject the null hypothesis"
else:
    decision = "Fail to reject the null hypothesis"

if decision == "Reject the null hypothesis":
    conclusion = "There is a significant difference in high engagement proportions between Account X and Account Y."
else:
    conclusion = "There is no significant difference in high engagement proportions between Account X and Account Y."

# Print the results
print(f"Decision: {decision}")
print(f"Conclusion: {conclusion}")
# Out:
# Z-statistic = -1.7191729277636834
# P-value = 0.08558288874449103
# Decision: Fail to reject the null hypothesis
# Conclusion: There is no significant difference in high engagement proportions between Account X and Account Y.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame({'Rating': [3.5, 4.2, 3.9, None, 4.8, None, 3.3, None, 4.5, 4.1, 3.7, None, 4.6]})

# %%
data
# Out:
#     Rating
# 0      3.5
# 1      4.2
# 2      3.9
# 3      NaN
# 4      4.8
# 5      NaN
# 6      3.3
# 7      NaN
# 8      4.5
# 9      4.1
# 10     3.7
# 11     NaN
# 12     4.6

# %%
data['Rating'].sum() / 9
# Out:
# 4.066666666666666

# %%
data['Rating'].mean()
# Out:
# 4.066666666666666

# %%
from sklearn.impute import SimpleImputer

# %%
imputer = SimpleImputer(strategy='most_frequent', fill_value=3.5)
data['Rating'] = imputer.fit_transform(data[['Rating']])

# %%
data
# Out:
#     Rating
# 0      3.5
# 1      4.2
# 2      3.9
# 3      3.3
# 4      4.8
# 5      3.3
# 6      3.3
# 7      3.3
# 8      4.5
# 9      4.1
# 10     3.7
# 11     3.3
# 12     4.6

# %%
imputer = SimpleImputer(strategy='median')
data['Rating'] = imputer.fit_transform(data[['Rating']])

# %%
data
# Out:
#     Rating
# 0      3.5
# 1      4.2
# 2      3.9
# 3      4.1
# 4      4.8
# 5      4.1
# 6      3.3
# 7      4.1
# 8      4.5
# 9      4.1
# 10     3.7
# 11     4.1
# 12     4.6

# %%
imputer = SimpleImputer(strategy='most_frequent')
data['Rating'] = imputer.fit_transform(data[['Rating']])
data
# Out:
#     Rating
# 0      3.5
# 1      4.2
# 2      3.9
# 3      3.3
# 4      4.8
# 5      3.3
# 6      3.3
# 7      3.3
# 8      4.5
# 9      4.1
# 10     3.7
# 11     3.3
# 12     4.6

# %%
imputer = SimpleImputer(strategy='constant', fill_value=3.5)
data['Rating'] = imputer.fit_transform(data[['Rating']])
data
# Out:
#     Rating
# 0      3.5
# 1      4.2
# 2      3.9
# 3      3.5
# 4      4.8
# 5      3.5
# 6      3.3
# 7      3.5
# 8      4.5
# 9      4.1
# 10     3.7
# 11     3.5
# 12     4.6

# %%
import numpy as np
from scipy.stats import norm

# Given data
population_mean = 1.7
sample_mean = 1.85
population_stddev = 0.5
sample_size = np.sqrt(60)
alpha = 0.05  # Significance level (1 - alpha will give us the confidence level)

# Calculate the critical value (Z) for a right-tailed test at the given alpha level
z_critical = norm.ppf(1 - alpha)

# Calculate the margin of error
margin_of_error = z_critical * (population_stddev / sample_size)

# Calculate the confidence interval
confidence_interval = (sample_mean - margin_of_error, sample_mean + margin_of_error)

print("Confidence Interval:", confidence_interval)


# Check if the population mean (1800) falls within the confidence interval

if confidence_interval[0] <= population_mean <= confidence_interval[1]:
    print("The population mean falls within the confidence interval. Then we fail to reject the null hypothesis")
else:
    print("The population mean does not fall within the confidence interval. Then we reject the null hypothesis")
# Out:
# Confidence Interval: (1.7438251549311348, 1.9561748450688654)
# The population mean does not fall within the confidence interval. Then we reject the null hypothesis

# %%
import numpy as np
from scipy.stats import norm

# Given data
mu = 1.7  # Population mean
sigma = 0.5  # Population standard deviation
n = 60  # Sample size
x_bar = 1.85  # Sample mean
alpha = 0.05  # Significance level

# Step 1: Compute the standard error of the mean
standard_error = sigma / np.sqrt(n)

# Step 2: Compute the z-score
z_score = (x_bar - mu) / standard_error

# Step 3: Determine critical values
z_critical = norm.ppf(1 - alpha/2)  # For two-tailed test

# Step 4: Compare the test statistic with the critical values
if z_score > z_critical or z_score < -z_critical:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")

# Step 5: Calculate the confidence interval
margin_of_error = z_critical * standard_error
lower_bound = x_bar - margin_of_error
upper_bound = x_bar + margin_of_error

print("Confidence Interval: ({:.4f}, {:.4f})".format(lower_bound, upper_bound))
# Out:
# Reject the null hypothesis.
# Confidence Interval: (1.7235, 1.9765)

# %%
import numpy as np
from scipy.stats import norm

# Given data
mu = 1.7  # Population mean
sigma = 0.5  # Population standard deviation
n = 60  # Sample size
x_bar = 1.85  # Sample mean
alpha = 0.05  # Significance level

# Step 1: Compute the standard error of the mean
standard_error = sigma / np.sqrt(n)

# Step 2: Compute the z-score
z_score = (x_bar - mu) / standard_error

# Step 3: Compute the p-value
p_value = 2 * (1 - norm.cdf(abs(z_score)))  # For two-tailed test
print(z_score)

# Step 4: Determine whether to reject or fail to reject the null hypothesis
if p_value < alpha:
    print("Reject the null hypothesis.")
else:
    print("Fail to reject the null hypothesis.")

# Step 5: Calculate the confidence interval
margin_of_error = norm.ppf(1 - alpha/2) * standard_error
lower_bound = x_bar - margin_of_error
upper_bound = x_bar + margin_of_error

print("Confidence Interval: ({:.4f}, {:.4f})".format(lower_bound, upper_bound))
# Out:
# 2.3237900077244524
# Reject the null hypothesis.
# Confidence Interval: (1.7235, 1.9765)

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Define the observed frequencies (cross-tabulation) of eye color and hair color
observed = np.array([[20, 94, 84, 17],   # Brown hair
                     [68, 7, 119, 26],     # Black hair
                     [5, 16, 29, 14],     # Blonde hair
                     [15, 10, 54, 14]])    # Red hair

# Perform the Chi-square test
chi2_stat, p_val, dof, expected = chi2_contingency(observed)

# Define the significance level
alpha = 0.01

# Print the test statistic, p-value, and expected frequencies
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_val)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)

# Compare the p-value with the significance level
if p_val < alpha:
    print("Reject the null hypothesis: There is a significant association between eye color and hair color.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between eye color and hair color.")
# Out:
# Chi-square statistic: 138.28984162600824
# P-value: 2.325286787098839e-25
# Degrees of freedom: 9
# Expected frequencies:
#  [[ 39.22297297  46.12331081 103.86824324  25.78547297]
#  [ 40.13513514  47.19594595 106.28378378  26.38513514]
#  [ 11.67567568  13.72972973  30.91891892   7.67567568]
#  [ 16.96621622  19.95101351  44.92905405  11.15371622]]
# Reject the null hypothesis: There is a significant association between eye color and hair color.

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Define the observed frequencies (cross-tabulation) of eye color and hair color
observed = np.array([[20, 94, 84, 17],
                     [68, 7, 119, 26],
                     [5, 16, 29, 14],
                     [15, 10, 54, 14]])

# Perform the Chi-square test
chi2_stat, p_val, dof, expected = chi2_contingency(observed)

# Define the significance level
alpha = 0.01

# Print the test statistic, p-value, and expected frequencies
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_val)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)

# Compare the p-value with the significance level
if p_val < alpha:
    print("Reject the null hypothesis: There is a significant association between eye color and hair color.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between eye color and hair color.")
# Out:
# Chi-square statistic: 138.28984162600824
# P-value: 2.325286787098839e-25
# Degrees of freedom: 9
# Expected frequencies:
#  [[ 39.22297297  46.12331081 103.86824324  25.78547297]
#  [ 40.13513514  47.19594595 106.28378378  26.38513514]
#  [ 11.67567568  13.72972973  30.91891892   7.67567568]
#  [ 16.96621622  19.95101351  44.92905405  11.15371622]]
# Reject the null hypothesis: There is a significant association between eye color and hair color.

# %%
observed.T
# Out:
# array([[ 20,  68,   5,  15],
#        [ 94,   7,  16,  10],
#        [ 84, 119,  29,  54],
#        [ 17,  26,  14,  14]])

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Define the observed frequencies (cross-tabulation) of eye color and hair color
observed = np.array([[20, 94, 84, 17],
                     [68, 7, 119, 26],
                     [5, 16, 29, 14],
                     [15, 10, 54, 14]])

abc = observed.T

# Perform the Chi-square test
chi2_stat, p_val, dof, expected = chi2_contingency(abc)

# Define the significance level
alpha = 0.01

# Print the test statistic, p-value, and expected frequencies
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_val)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)

# Compare the p-value with the significance level
if p_val < alpha:
    print("Reject the null hypothesis: There is a significant association between eye color and hair color.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between eye color and hair color.")
# Out:
# Chi-square statistic: 138.28984162600827
# P-value: 2.3252867870988044e-25
# Degrees of freedom: 9
# Expected frequencies:
#  [[ 39.22297297  40.13513514  11.67567568  16.96621622]
#  [ 46.12331081  47.19594595  13.72972973  19.95101351]
#  [103.86824324 106.28378378  30.91891892  44.92905405]
#  [ 25.78547297  26.38513514   7.67567568  11.15371622]]
# Reject the null hypothesis: There is a significant association between eye color and hair color.

# %%
import numpy as np
from scipy.stats import chi2_contingency

# Define the observed frequencies (cross-tabulation) of eye color and hair color
observed = np.array([[20, 94, 84, 17],
                     [68, 7, 119, 26],
                     [5, 16, 29, 14],
                     [15, 10, 54, 14]])

# Perform the Chi-square test for independence
chi2_stat, p_val, dof, expected = chi2_contingency(observed)

# Define the significance level
alpha = 0.01

# Print the test statistic, p-value, and expected frequencies
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_val)
print("Degrees of freedom:", dof)
print("Expected frequencies:\n", expected)

# Compare the p-value with the significance level
if p_val < alpha:
    print("p-value < alpha: Reject the null hypothesis.")
    print("Yes, there is a statistically significant relationship between eye and hair color.")
else:
    print("p-value >= alpha: Fail to reject the null hypothesis.")
    print("No, there is no statistically significant relationship between eye and hair color.")
# Out:
# Chi-square statistic: 138.28984162600824
# P-value: 2.325286787098839e-25
# Degrees of freedom: 9
# Expected frequencies:
#  [[ 39.22297297  46.12331081 103.86824324  25.78547297]
#  [ 40.13513514  47.19594595 106.28378378  26.38513514]
#  [ 11.67567568  13.72972973  30.91891892   7.67567568]
#  [ 16.96621622  19.95101351  44.92905405  11.15371622]]
# p-value < alpha: Reject the null hypothesis.
# Yes, there is a statistically significant relationship between eye and hair color.

# %% [markdown]
# A French cafe has historically maintained that their average daily pastry production is at most 500.
#
# With the installation of a new machine, they assert that the average daily pastry production has increased. The average number of pastries produced per day over a 70-day period was found to be 530.
#
# Assume that the population standard deviation for the pastries produced per day is 125.
#
# Perform a z-test with the critical z-value = 1.64 at the alpha (significance level) = 0.05 to evaluate if there's sufficient evidence to support their claim of the new machine producing more than 500 pastries daily.
#
# Note: Round off the z-score to two decimal places.

# %%
array = [ [1, [ [ 2 ] ], [ [ [ 3 ] ] ], [ [ 4 ], 5 ] ]]
result = lambda x: sum(map(result, x), [ ] ) if isinstance(x, list) else [x]
print(result(array))
# Out:
# [1, 2, 3, 4, 5]
